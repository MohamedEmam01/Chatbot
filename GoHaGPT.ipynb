# %% [markdown]
# # Required Libraries

# %%
# tensorflow==2.3.1
# nltk==3.5
# colorama==0.4.3
# numpy==1.18.5
# scikit_learn==0.23.2
# Flask==1.1.2

# %% [markdown]
# # Import Library

# %%
import json
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder
# Out:
# WARNING:tensorflow:From C:\conda11\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # Uplaod data

# %%
# Loading data from 'intents.json'
with open('intents.json') as file:
    intents = json.load(file)

# Loading data from 'Intent.json' with 'utf-8' encoding
with open('Intent.json', encoding='utf-8') as file:
    Intent = json.load(file)

# Loading data from 'intents_arabic.json' with 'utf-8' encoding
with open('intents_arabic.json', encoding='utf-8') as file:
    intents_arabic = json.load(file)

# Loading data from 'country.json'
with open("country.json") as file:
    country = json.load(file)

# Printing loaded data from each file
print(intents)
print(Intent)
print(intents_arabic)
print(country)
# Out:
# {'intents': [{'tag': 'greeting', 'patterns': ['Hi', 'Hey', 'How are you', 'Is anyone there?', 'Hello', 'Good day'], 'responses': ['Hi :)', 'Hey :-)', "I'm fine, what can I do for you?", 'Hi there, how can I help?', 'Hello', 'Thanks for visiting']}, {'tag': 'goodbye', 'patterns': ['Bye', 'See you later', 'Goodbye', 'See you soon', 'See you later'], 'responses': ['Have a nice day', 'See you later, thanks for visiting', 'Goodbye!', 'Bye, see you soon!', 'Bye! Come back again soon.', 'Take care!', 'Have a great day!']}, {'tag': 'thanks', 'patterns': ['Thanks', 'Thank you', "That's helpful", "Thank's a lot!", 'Thanks for the help'], 'responses': ['Happy to help!', 'Any time!', 'My pleasure', "You're most welcome!"]}, {'tag': 'about', 'patterns': ['Who are you?', 'What are you?', 'Who you are?', 'Who you doing?', 'What are you doing?'], 'responses': ["I'm H, an Artificial Intelligent bot", "I'm Hesho, your bot assistant", "I'm H, your friend!", 'I do what you need in app?']}, {'tag': 'name', 'patterns': ['what is your name', 'what should I call you', 'whats your name?'], 'responses': ['You can call me Hesho.', "I'm 2sho !", 'Just call me as Moody']}, {'tag': 'help', 'patterns': ['Could you help me?', 'give me a hand please', 'Can you help?', 'What can you do for me?', 'I need a support', 'I need a help', 'support me please'], 'responses': ['Tell me how can assist you', 'Tell me your problem to assist you', 'Yes Sure, How can I support you']}, {'tag': 'electrical', 'patterns': ['How do I connect an electrical socket?', 'What tools are required to install an electrical switch?', 'How do I change a household light bulb?', 'Can I install a ceiling fan by myself?'], 'responses': ["You need to correctly identify the wires and follow the appropriate wiring diagram. It's advisable to consult an electrician if you're not sure.", 'Tools required include a level, wiring instructions, new wires if necessary, and wire cutters. Follow safety procedures while working.', 'Use safety equipment and turn off the power before changing a light bulb. Wear protective gloves.', "You can install a ceiling fan by yourself, but follow the manufacturer's instructions carefully."]}, {'tag': 'plumbing', 'patterns': ['How can I fix a leak in the sink?', 'What are the steps to install a new faucet?', 'How do I clean the kitchen drain?', 'How can I prevent water pipes from freezing in winter?'], 'responses': ["Close the main water valve before fixing a sink leak. It's important to act promptly.", 'To install a new faucet, connect the hose to the water line and secure it properly.', 'Regularly clear debris and food particles from the kitchen drain to prevent clogs.', 'Insulate pipes in cold areas using pipe insulation, and leave faucets dripping to prevent freezing.']}, {'tag': 'carpentry', 'patterns': ['How do I measure wood accurately for cutting?', "What's the best way to install hardwood flooring?", 'How can I achieve a smooth edge when woodworking?', 'Can I repair wooden furniture myself?'], 'responses': ['Use a ruler and a measuring tape to accurately measure wood before cutting.', 'Ensure a level surface and use glue and nails to secure hardwood flooring.', 'Use a variety of sandpaper grits to achieve a smooth wooden edge.', 'You can perform simple repairs on wooden furniture using glue and screws, but major repairs may require a furniture expert.']}, {'tag': 'electrical_2', 'patterns': ['What are the basic safety requirements when working with electricity?', "How can I test an electrical wire to ensure it's safe?", "What's the difference between direct current (DC) and alternating current (AC)?"], 'responses': ['Wear safety gear like gloves and safety goggles when working with electricity. Always turn off power before starting any work.', 'Use a voltage tester to test electrical wires. Ensure power is cut off before testing.', 'DC flows in one direction, while AC changes direction periodically. AC is the most common type of current used in homes.']}, {'tag': ...
# {'intents': [{'tag': 'Greeting', 'patterns': ['Hi', 'Hi there', 'Hola', 'Hello', 'Hello there', 'Hya', 'Hya there'], 'responses': ['Hi human, please tell me your GeniSys user', 'Hello human, please tell me your GeniSys user', 'Hola human, please tell me your GeniSys user'], 'extension': {'function': '', 'entities': False, 'responses': []}, 'contexts': {'in': '', 'out': 'GreetingUserRequest', 'clear': False}, 'entityType': 'NA', 'entities': []}, {'tag': 'GreetingResponse', 'patterns': ['My user is Adam', 'This is Adam', 'I am Adam', 'It is Adam', 'My user is Bella', 'This is Bella', 'I am Bella', 'It is Bella'], 'responses': ['Great! Hi <HUMAN>! How can I help?', 'Good! Hi <HUMAN>, how can I help you?', 'Cool! Hello <HUMAN>, what can I do for you?', 'OK! Hola <HUMAN>, how can I help you?', 'OK! hi <HUMAN>, what can I do for you?'], 'extension': {'function': 'extensions.gHumans.updateHuman', 'entities': True, 'responses': ['Hi %%HUMAN%%! How can I help?', 'Hi %%HUMAN%%, how can I help you?', 'Hello %%HUMAN%%, what can I do for you?', 'Hola %%HUMAN%%, how can I help you?', 'OK hi %%HUMAN%%, what can I do for you?']}, 'contexts': {'in': 'GreetingUserRequest', 'out': '', 'clear': True}, 'entityType': 'NA', 'entities': [{'entity': 'HUMAN', 'rangeFrom': 3, 'rangeTo': 4}, {'entity': 'HUMAN', 'rangeFrom': 2, 'rangeTo': 3}, {'entity': 'HUMAN', 'rangeFrom': 1, 'rangeTo': 2}, {'entity': 'HUMAN', 'rangeFrom': 2, 'rangeTo': 3}, {'entity': 'HUMAN', 'rangeFrom': 3, 'rangeTo': 4}, {'entity': 'HUMAN', 'rangeFrom': 2, 'rangeTo': 3}, {'entity': 'HUMAN', 'rangeFrom': 1, 'rangeTo': 2}, {'entity': 'HUMAN', 'rangeFrom': 2, 'rangeTo': 3}]}, {'tag': 'CourtesyGreeting', 'patterns': ['How are you?', 'Hi how are you?', 'Hello how are you?', 'Hola how are you?', 'How are you doing?', 'Hope you are doing well?', 'Hello hope you are doing well?'], 'responses': ['Hello, I am great, how are you? Please tell me your GeniSys user', 'Hello, how are you? I am great thanks! Please tell me your GeniSys user', 'Hello, I am good thank you, how are you? Please tell me your GeniSys user', 'Hi, I am great, how are you? Please tell me your GeniSys user', 'Hi, how are you? I am great thanks! Please tell me your GeniSys user', 'Hi, I am good thank you, how are you? Please tell me your GeniSys user', 'Hi, good thank you, how are you? Please tell me your GeniSys user'], 'extension': {'function': '', 'entities': False, 'responses': []}, 'contexts': {'in': '', 'out': 'CourtesyGreetingUserRequest', 'clear': True}, 'entityType': 'NA', 'entities': []}, {'tag': 'CourtesyGreetingResponse', 'patterns': ['Good thanks! My user is Adam', 'Good thanks! This is Adam', 'Good thanks! I am Adam', 'Good thanks! It is Adam', 'Great thanks! My user is Bella', 'Great thanks! This is Bella', 'Great thanks! I am Bella', 'Great thanks! It is Bella'], 'responses': ['Great! Hi <HUMAN>! How can I help?', 'Good! Hi <HUMAN>, how can I help you?', 'Cool! Hello <HUMAN>, what can I do for you?', 'OK! Hola <HUMAN>, how can I help you?', 'OK! hi <HUMAN>, what can I do for you?'], 'extension': {'function': 'extensions.gHumans.updateHuman', 'entities': True, 'responses': ['Great %%HUMAN%%! How can I help?', 'Good %%HUMAN%%, how can I help you?', 'Cool %%HUMAN%%, what can I do for you?', 'OK %%HUMAN%%, how can I help you?', 'OK hi %%HUMAN%%, what can I do for you?']}, 'contexts': {'in': 'GreetingUserRequest', 'out': '', 'clear': True}, 'entityType': 'NA', 'entities': [{'entity': 'HUMAN', 'rangeFrom': 5, 'rangeTo': 6}, {'entity': 'HUMAN', 'rangeFrom': 4, 'rangeTo': 5}, {'entity': 'HUMAN', 'rangeFrom': 3, 'rangeTo': 4}, {'entity': 'HUMAN', 'rangeFrom': 4, 'rangeTo': 5}, {'entity': 'HUMAN', 'rangeFrom': 5, 'rangeTo': 6}, {'entity': 'HUMAN', 'rangeFrom': 4, 'rangeTo': 5}, {'entity': 'HUMAN', 'rangeFrom': 3, 'rangeTo': 4}, {'entity': 'HUMAN', 'rangeFrom': 3, 'rangeTo': 4}]}, {'tag': 'CurrentHumanQuery', 'patterns': ['What is my name?', 'What do you call me?', 'Who do you think I am?', 'What do you think I am?', 'Who ...
# {'intents': [{'tag': 'electrical', 'patterns': ['ما هو الفرق بين الجهد والتيار الكهربائي؟', 'كيف يمكنني اختيار قاطع الدائرة المناسب؟', 'ما هو دور الأرضي في الدوائر الكهربائية؟'], 'responses': ['الجهد يقاس بالفولت وهو فارق الكهرباء بين نقطتين. التيار يقاس بالأمبير وهو تدفق الكهرباء في الدائرة.', 'اختيار قاطع الدائرة يعتمد على تقدير الحمل الكهربائي والتيار المناسب للدائرة.', 'الأرضي يساعد في توجيه الكهرباء الزائدة إلى الأرض لمنع التيار الزائد وحماية الأفراد والأجهزة.']}, {'tag': 'plumbing', 'patterns': ['ما هو أفضل نوع من الأنابيب للسباكة؟', 'كيف يمكنني إصلاح تسرب في الأنابيب النحاسية؟', 'كيف أقوم بتجنب تجمد الأنابيب في فصل الشتاء؟'], 'responses': ['البلاستيك والنحاس من أنواع الأنابيب المستخدمة بشكل شائع. اختيار النوع يعتمد على الاحتياجات والبيئة.', 'قم بتنظيف المنطقة المتضررة واستخدم شريط الإصلاح الخاص بالأنابيب النحاسية.', 'قم بعزل الأنابيب في المناطق الباردة باستخدام عازل حراري واترك صنبورًا ينقط بانتظام لتجنب التجمد.']}, {'tag': 'carpentry', 'patterns': ['ما هي أهم الأدوات المطلوبة لبناء مشروع خشبي؟', 'كيف يمكنني عمل مفصلات خشبية متينة؟', 'ما هي أفضل طريقة لتلميع الأثاث الخشبي؟'], 'responses': ['الأدوات المهمة تشمل المنشار الدائري، المسطرة، المثقاب، ومجموعة متنوعة من الأدوات اليدوية.', 'استخدم مفصلات عالية الجودة واتبع تعليمات الإرفاق بدقة لضمان متانة المفصلات الخشبية.', 'استخدم ورق الصنفرة الناعم لتلميع الأثاث الخشبي ويمكنك استخدام طبقة رقيقة من الورنيش لحماية السطح.']}, {'tag': 'electrical', 'patterns': ['ما هي متطلبات السلامة الأساسية عند التعامل مع الكهرباء؟', 'كيف يمكنني اختبار سلك كهربائي للتأكد من سلامته؟', 'ما هو الفرق بين التيار المستمر والتيار المتردد؟'], 'responses': ['ارتد معدات السلامة مثل القفازات والنظارات عند التعامل مع الكهرباء. قم بفصل الطاقة قبل البدء.', 'استخدم جهاز اختبار الجهد لاختبار سلك الكهرباء. تأكد من قطع التيار قبل الاختبار.', 'التيار المستمر يتدفق في اتجاه واحد، بينما التيار المتردد يتغير اتجاهه بانتظام. التيار المتردد هو النوع الأكثر شيوعًا في المنازل.']}, {'tag': 'plumbing', 'patterns': ['ما هي أسباب تسرب المياه في الحمام؟', 'كيف يمكنني تركيب مرحاض جديد بنفسي؟', 'ما هي أفضل طريقة لتسريب أنبوب المياه؟'], 'responses': ['تسرب المياه في الحمام قد يكون نتيجة لخراب الأختام أو التصاق الجير. يجب إصلاحه فورًا.', 'تركيب المرحاض الجديد يتطلب توصيل الخرطوم بخط المياه وتثبيته بشكل آمن في مكانه.', 'استخدم شريط الفولاذ لتسريب أنبوب المياه. ضعه حول الانبوب وأغلقه بإحكام.']}, {'tag': 'carpentry', 'patterns': ['ما هي أنواع الخشب المناسبة لصنع الأثاث؟', 'كيف يمكنني تثبيت قطع الخشب معًا بشكل محكم؟', 'كيف يمكنني تلميع السطح الخشبي بمظهر طبيعي؟'], 'responses': ['أنواع الخشب المناسبة تشمل البلوط والقيقب والصنوبر. اختيار النوع يعتمد على التصميم والاستخدام.', 'استخدم مسامير وغراء قوي لتثبيت قطع الخشب معًا. يمكن استخدام المشابك لتثبيتها حتى يجف الغراء.', 'استخدم ورق الصنفرة والورنيش الشفاف لتلميع السطح وإبراز جمال الخشب.']}, {'tag': 'electrical', 'patterns': ['ما هو دور مكثف البدء في محرك الغسالة؟', 'كيف يمكنني إصلاح مأخذ كهربائي لا يعمل؟', 'هل يمكنني تركيب أسلاك كهربائية خارجية؟'], 'responses': ['مكثف البدء يساعد في بدء تشغيل محرك الغسالة وتوفير الزخم اللازم لبدء الدوران.', 'افحص الدائرة الكهربائية وتأكد من وجود توصيل سليم. قد تحتاج إلى استدعاء فني كهربائي إذا لم تستطيع إصلاحه بنفسك.', 'يجب تركيب الأسلاك الكهربائية داخل الجدران وبشكل آمن. تركيب الأسلاك الخارجية قد يكون خطرًا.']}, {'tag': 'plumbing', 'patterns': ['ما هي طرق إصلاح تسرب في الأنابيب البلاستيكية؟', 'كيف يمكنني تركيب حنفية المطبخ؟', 'كيف يمكنني تنظيف المصرف الصحي الخاص بالحمام؟'], 'responses': ['استخدم شريط إصلاح الأنابيب البلاستيكية لسد التسرب. يمكنك أيضًا استبدال جزء من الأنبوب المتضرر.', 'اتبع تعليمات الشركة المصنعة لتركيب حنفية المطبخ. قد تحتاج إلى أدوات أساسية مثل مفك ومشابك.', 'استخدم أسطوانة أسلاك لإزالة الشعر والشوائب من المصرف الصحي. قم بتنظيفه بالماء الساخن بانتظام.']}, {'tag': 'carpentry', 'patterns': ['ما هي الأخشاب المناسبة لصنع الأثاث الخارجي؟', 'كيف يمكنني عمل تصميم معقد باستخدام الخشب؟', 'ما هي أفضل طريقة لإصلاح تشققات الخشب؟'], 'responses': ['الأخشاب المقاومة للعوامل الجوية مثل السديم والأوكالبتوس مناسبة للأثاث الخارجي.', 'قم برسم التصميم بد ...
# {'intents': [{'tag': 'capital_query', 'patterns': ['What is the capital of Albania?', 'What is the capital of Algeria?', 'What is the capital of Andorra?', 'What is the capital of Angola?', 'What is the capital of Antigua and Barbuda?', 'What is the capital of Argentina?', 'What is the capital of Armenia?', 'What is the capital of Australia?', 'What is the capital of Austria?', 'What is the capital of Azerbaijan?', 'What is the capital of Bahamas?', 'What is the capital of Bahrain?', 'What is the capital of Bangladesh?', 'What is the capital of Barbados?', 'What is the capital of Belarus?', 'What is the capital of Belgium?', 'What is the capital of Belize?', 'What is the capital of Benin?', 'What is the capital of Bhutan?', 'What is the capital of Bolivia?', 'What is the capital of Bosnia and Herzegovina?', 'What is the capital of Botswana?', 'What is the capital of Brazil?', 'What is the capital of Brunei?', 'What is the capital of Bulgaria?', 'What is the capital of Burkina Faso?', 'What is the capital of Burundi?', 'What is the capital of Cabo Verde?', 'What is the capital of Cambodia?', 'What is the capital of Cameroon?', 'What is the capital of Canada?', 'What is the capital of Central African Republic?', 'What is the capital of Chad?', 'What is the capital of Chile?', 'What is the capital of China?', 'What is the capital of Colombia?', 'What is the capital of Comoros?', 'What is the capital of Congo (Congo-Brazzaville)?', 'What is the capital of Costa Rica?', 'What is the capital of Croatia?', 'What is the capital of Cuba?', 'What is the capital of Cyprus?', 'What is the capital of Czech Republic?', 'What is the capital of DR Congo (Congo-Kinshasa)?', 'What is the capital of Denmark?', 'What is the capital of Djibouti?', 'What is the capital of Dominica?', 'What is the capital of Dominican Republic?', 'What is the capital of East Timor (Timor-Leste)?', 'What is the capital of Ecuador?', 'What is the capital of Egypt?', 'What is the capital of El Salvador?', 'What is the capital of Equatorial Guinea?', 'What is the capital of Eritrea?', 'What is the capital of Estonia?', 'What is the capital of Ethiopia?', 'What is the capital of Fiji?', 'What is the capital of Finland?', 'What is the capital of France?', 'What is the capital of Gabon?', 'What is the capital of Gambia?', 'What is the capital of Georgia?', 'What is the capital of Germany?', 'What is the capital of Ghana?', 'What is the capital of Greece?', 'What is the capital of Grenada?', 'What is the capital of Guatemala?', 'What is the capital of Guinea?', 'What is the capital of Guinea-Bissau?', 'What is the capital of Guyana?', 'What is the capital of Haiti?', 'What is the capital of Honduras?', 'What is the capital of Hungary?', 'What is the capital of Iceland?', 'What is the capital of India?', 'What is the capital of Indonesia?', 'What is the capital of Iran?', 'What is the capital of Iraq?', 'What is the capital of Ireland?', 'What is the capital of Israel?', 'What is the capital of Italy?', 'What is the capital of Ivory Coast?', 'What is the capital of Jamaica?', 'What is the capital of Japan?', 'What is the capital of Jordan?', 'What is the capital of Kazakhstan?', 'What is the capital of Kenya?', 'What is the capital of Kiribati?', 'What is the capital of Kosovo?', 'What is the capital of Kuwait?', 'What is the capital of Kyrgyzstan?', 'What is the capital of Laos?', 'What is the capital of Latvia?', 'What is the capital of Lebanon?', 'What is the capital of Lesotho?', 'What is the capital of Liberia?', 'What is the capital of Libya?', 'What is the capital of Liechtenstein?', 'What is the capital of Lithuania?', 'What is the capital of Luxembourg?', 'What is the capital of Madagascar?', 'What is the capital of Malawi?', 'What is the capital of Malaysia?', 'What is the capital of Maldives?', 'What is the capital of Mali?', 'What is the capital of Malta?', 'What is the capital of Marshall Islands?', 'What is the capital of Mauritania?', 'What is the capital of M ...

# %%
# Iterating through each 'intent' in the 'intents' list inside the 'country' dictionary
for intent in country['intents']:
    # Iterating through the range of indices of 'patterns' in each 'intent'
    for pattern_index in range(len(intent['patterns'])):
        # Accessing each 'pattern' in the 'patterns' list of the current 'intent'
        pattern = intent['patterns'][pattern_index]
        # Removing specific characters ('{', '!', '%', '?') and converting to lowercase
        cleaned_pattern = pattern.replace('{', '').replace('!', '').replace('%', '').replace('?', '').lower()
        # Replacing the original pattern with the cleaned pattern in the 'patterns' list
        intent['patterns'][pattern_index] = cleaned_pattern

# Displaying the modified 'country' data in JSON format with indentation for readability
print(json.dumps(country, indent=4))
# Out:
# {
#     "intents": [
#         {
#             "tag": "capital_query",
#             "patterns": [
#                 "what is the capital of albania",
#                 "what is the capital of algeria",
#                 "what is the capital of andorra",
#                 "what is the capital of angola",
#                 "what is the capital of antigua and barbuda",
#                 "what is the capital of argentina",
#                 "what is the capital of armenia",
#                 "what is the capital of australia",
#                 "what is the capital of austria",
#                 "what is the capital of azerbaijan",
#                 "what is the capital of bahamas",
#                 "what is the capital of bahrain",
#                 "what is the capital of bangladesh",
#                 "what is the capital of barbados",
#                 "what is the capital of belarus",
#                 "what is the capital of belgium",
#                 "what is the capital of belize",
#                 "what is the capital of benin",
#                 "what is the capital of bhutan",
#                 "what is the capital of bolivia",
#                 "what is the capital of bosnia and herzegovina",
#                 "what is the capital of botswana",
#                 "what is the capital of brazil",
#                 "what is the capital of brunei",
#                 "what is the capital of bulgaria",
#                 "what is the capital of burkina faso",
#                 "what is the capital of burundi",
#                 "what is the capital of cabo verde",
#                 "what is the capital of cambodia",
#                 "what is the capital of cameroon",
#                 "what is the capital of canada",
#                 "what is the capital of central african republic",
#                 "what is the capital of chad",
#                 "what is the capital of chile",
#                 "what is the capital of china",
#                 "what is the capital of colombia",
#                 "what is the capital of comoros",
#                 "what is the capital of congo (congo-brazzaville)",
#                 "what is the capital of costa rica",
#                 "what is the capital of croatia",
#                 "what is the capital of cuba",
#                 "what is the capital of cyprus",
#                 "what is the capital of czech republic",
#                 "what is the capital of dr congo (congo-kinshasa)",
#                 "what is the capital of denmark",
#                 "what is the capital of djibouti",
#                 "what is the capital of dominica",
#                 "what is the capital of dominican republic",
#                 "what is the capital of east timor (timor-leste)",
#                 "what is the capital of ecuador",
#                 "what is the capital of egypt",
#                 "what is the capital of el salvador",
#                 "what is the capital of equatorial guinea",
#                 "what is the capital of eritrea",
#                 "what is the capital of estonia",
#                 "what is the capital of ethiopia",
#                 "what is the capital of fiji",
#                 "what is the capital of finland",
#                 "what is the capital of france",
#                 "what is the capital of gabon",
#                 "what is the capital of gambia",
#                 "what is the capital of georgia",
#                 "what is the capital of germany",
#                 "what is the capital of ghana",
#                 "what is the capital of greece",
#                 "what is the capital of grenada",
#                 "what is the capital of guatemala",
#                 "what is the capital of guinea",
#                 "what is the capital of guinea-bissau",
#                 "what is the capital of guyana",
#                 "what is the capital of haiti",
#                 "what is the capital of honduras",
#                 "what is the capital of hungary",
#                 "what is the capital of iceland",
#                 "what is the capital of india",
#                 "what is the capital of indonesia",
#                 "what is the capital of iran",
#                 "what is the capital of iraq",
#                 "what is the capital of ireland",
#                 "what is the capital of israel",
#                 "what is the capital of italy",
#                 "what is the capital of ivory coast",
#                 "what is the capital of jamaica",
#                 "what is the capital of japan",
#                 "what is the capital of jordan",
#                 "what is the capital of kazakhstan",
#                 "what is the capital of kenya",
#                 "what is the capital of kiribati",
#                 "what is the capital of kosovo",
#                 "what is the capital of kuwait",
#                 "what is the capital of kyrgyzstan",
#                 "what is the capital of laos",
#                 "what is the capital of latvia",
#                 "what is the capital of lebanon",
#                 "what is the capital of lesotho",
#                 "what is the capital of liberia",
#                 "what is the capital of libya",
#                 "what is the capital of liechtenstein",
#                 "what is the capital of lithuania",
#                 "what is the capital of luxembourg",
#                 "what is the capital of madagascar",
#                 "what is the capital of malawi",
#                 "what is the capital of malaysia",
#                 "what is the capital of maldives",
#                 "what is the capital of mali",
#                 "what is the capital of malta",
#                 "what is the capital of marshall islands",
#                 "what is the capital of mauritania",
#                 "what is the capital of mauritius",
#                 "what is the capital of mexico",
#                 "what is the capital of micronesia",
#                 "what is the capital of moldova",
#                 "what is the capital of monaco",
#                 "what is the capital of mongolia",
#                 "what is the capital of montenegro",
#                 "what is the capital of morocco",
#                 "what is the capital of mozambique",
#                 "what is the capital of myanmar (burma)",
#                 "what is the capital of namibia",
#                 "what is the capital of nauru",
#                 "what is the capital of nepal",
#                 "what is the capital of netherlands",
#                 "what is the capital of new zealand",
#                 "what is the capital of nicaragua",
#                 "what is the capital of niger",
#                 "what is the capital of nigeria",
#                 "what is the capital of north korea",
#                 "what is the capital of north macedonia (fmr. macedonia)",
#                 "what is the capital of norway",
#                 "what is the capital of oman",
#                 "what is the capital of pakistan",
#                 "what is the capital of palau",
#                 "what is the capital of panama",
#                 "what is the capital of papua new guinea",
#                 "what is the capital of paraguay",
#                 "what is the capital of peru",
#                 "what is the capital of philippines",
#                 "what is the capital of poland",
#                 "what is the capital of portugal",
#                 "what is the capital of qatar",
#                 "what is the capital of romania",
#                 "what is the capital of russia",
#                 "what is the capital of rwanda",
#                 "what is the capital of saint kitts and nevis",
#                 "what is the capital of saint lucia",
#                 "what is the capital of saint vincent and the grenadines",
#                 "what is the capital of samoa",
#                 "what is the capital of san marino",
#                 "what is the capital of sao tome and principe",
#                 "what is the capital of saudi arabia",
#                 "what is the capital of senegal",
#                 "what is the capital of serbia",
#                 "what is the capital of seychelles",
#                 "what is the capital of sierra leone",
#                 "what is the capital of singapore",
#                 "what is the capital of slovakia",
#                 "what is the capital of slovenia",
#                 "what is the capital of solomon islands",
#                 "what is the capital of somalia",
#                 "what is the capital of south africa",
#                 "what is the capital of south korea",
#                 "what is the capital of south sudan",
#                 "what is the capital of spain",
#                 "what is the capital of sri lanka",
#                 "what is the capital of sudan",
#                 "what is the capital of suriname",
#                 "what is the capital of sweden",
#                 "what is the capital of switzerland",
#                 "what is the capital of syria",
#                 "what is the capital of taiwan",
#                 "what is the capital of tajikistan",
#                 "what is the capital of tanzania",
#                 "what is the capital of thailand",
#                 "what is the capital of togo",
#                 "what is the capital of tonga",
#                 "what is the capital of trinidad and tobago",
#                 "what is the capital of tunisia",
#                 "what is the capital of turkey",
#                 "what is the capital of turkmenistan",
#                 "what is the capital of tuvalu",
#                 "what is the capital of uganda",
#                 "what is the capital of ukraine",
#                 "what is the capital of united arab emirates",
#                 "what is the capital of united kingdom",
#                 "what is the capital of united states",
#                 "what is the capital of uruguay",
#                 "what is the capital of uzbekistan",
#                 "what is the capital of vanuatu",
#                 "what is the capital of vatican city",
#                 "what is the capital of venezuela",
#                 "what is the capital of vietnam",
#                 "what is the capital of yemen",
#                 "what is the capital of zambia",
#                 "what is the capital of zimbabwe"
#             ],
#             "responses": [
#                 "The capital of Albania is Tirana",
#                 "The capital of Algeria is Algiers",
#                 "The capital of Andorra is Andorra la Vella",
#                 "The capital of Angola is Luanda",
#                 "The capital of Antigua and Barbuda is St. John's",
#                 "The capital of Argentina is Buenos Aires",
#                 "The capital of Armenia is Yerevan",
#                 "The capital of Australia is Canberra",
#                 "The capital of Austria is Vienna",
#                 "The capital of Azerbaijan is Baku",
#                 "The capital of Bahamas is Nassau",
#                 "The capital of Bahrain is Manama",
#                 "The capital of Bangladesh is Dhaka",
#                 "The capital of Barbados is Bridgetown",
#                 "The capital of Belarus is Minsk",
#                 "The capital of Belgium is Brussels",
#                 "The capital of Belize is Belmopan",
#                 "The capital of Benin is Porto-Novo",
#                 "The capital of Bhutan is Thimphu",
#                 "The capital of Bolivia is Sucre, La Paz",
#                 "The capital of Bosnia and Herzegovina is Sarajevo",
#                 "The capital of Botswana is Gaborone",
#                 "The capital of Brazil is Bras\u0623\u00adlia",
#                 "The capital of Brunei is Bandar Seri Begawan",
#                 "The capital of Bulgaria is Sofia",
#                 "The capital of Burkina Faso is Ouagadougou",
#                 "The capital of Burundi is Gitega",
#                 "The capital of Cabo Verde is Praia",
#                 "The capital of Cambodia is Phnom Penh",
#                 "The capital of Cameroon is Yaound\u0623\u00a9",
#                 "The capital of Canada is Ottawa",
#                 "The capital of Central African Republic is Bangui",
#                 "The capital of Chad is N'Djamena",
#                 "The capital of Chile is Santiago",
#                 "The capital of China is Beijing",
#                 "The capital of Colombia is Bogot\u0623\u060c",
#                 "The capital of Comoros is Moroni",
#                 "The capital of Congo (Congo-Brazzaville) is Brazzaville",
#                 "The capital of Costa Rica is San Jos\u0623\u00a9",
#                 "The capital of Croatia is Zagreb",
#                 "The capital of Cuba is Havana",
#                 "The capital of Cyprus is Nicosia",
#                 "The capital of Czech Republic is Prague",
#                 "The capital of DR Congo (Congo-Kinshasa) is Kinshasa",
#                 "The capital of Denmark is Copenhagen",
#                 "The capital of Djibouti is Djibouti",
#                 "The capital of Dominica is Roseau",
#                 "The capital of Dominican Republic is Santo Domingo",
#                 "The capital of East Timor (Timor-Leste) is Dili",
#                 "The capital of Ecuador is Quito",
#                 "The capital of Egypt is Cairo",
#                 "The capital of El Salvador is San Salvador",
#                 "The capital of Equatorial Guinea is Malabo",
#                 "The capital of Eritrea is Asmara",
#                 "The capital of Estonia is Tallinn",
#                 "The capital of Ethiopia is Addis Ababa",
#                 "The capital of Fiji is Suva",
#                 "The capital of Finland is Helsinki",
#                 "The capital of France is Paris",
#                 "The capital of Gabon is Libreville",
#                 "The capital of Gambia is Banjul",
#                 "The capital of Georgia is Tbilisi",
#                 "The capital of Germany is Berlin",
#                 "The capital of Ghana is Accra",
#                 "The capital of Greece is Athens",
#                 "The capital of Grenada is St. George's",
#                 "The capital of Guatemala is Guatemala City",
#                 "The capital of Guinea is Conakry",
#                 "The capital of Guinea-Bissau is Bissau",
#                 "The capital of Guyana is Georgetown",
#                 "The capital of Haiti is Port-au-Prince",
#                 "The capital of Honduras is Tegucigalpa",
#                 "The capital of Hungary is Budapest",
#                 "The capital of Iceland is Reykjavik",
#                 "The capital of India is New Delhi",
#                 "The capital of Indonesia is Jakarta",
#                 "The capital of Iran is Tehran",
#                 "The capital of Iraq is Baghdad",
#                 "The capital of Ireland is Dublin",
#                 "The capital of Israel is Jerusalem",
#                 "The capital of Italy is Rome",
#                 "The capital of Ivory Coast is Yamoussoukro, Abidjan",
#                 "The capital of Jamaica is Kingston",
#                 "The capital of Japan is Tokyo",
#                 "The capital of Jordan is Amman",
#                 "The capital of Kazakhstan is Nur-Sultan",
#                 "The capital of Kenya is Nairobi",
#                 "The capital of Kiribati is South Tarawa",
#                 "The capital of Kosovo is Pristina",
#                 "The capital of Kuwait is Kuwait City",
#                 "The capital of Kyrgyzstan is Bishkek",
#                 "The capital of Laos is Vientiane",
#                 "The capital of Latvia is Riga",
#                 "The capital of Lebanon is Beirut",
#                 "The capital of Lesotho is Maseru",
#                 "The capital of Liberia is Monrovia",
#                 "The capital of Libya is Tripoli",
#                 "The capital of Liechtenstein is Vaduz",
#                 "The capital of Lithuania is Vilnius",
#                 "The capital of Luxembourg is Luxembourg City",
#                 "The capital of Madagascar is Antananarivo",
#                 "The capital of Malawi is Lilongwe",
#                 "The capital of Malaysia is Kuala Lumpur",
#                 "The capital of Maldives is Mal\u0623\u00a9",
#                 "The capital of Mali is Bamako",
#                 "The capital of Malta is Valletta",
#                 "The capital of Marshall Islands is Majuro",
#                 "The capital of Mauritania is Nouakchott",
#                 "The capital of Mauritius is Port Louis",
#                 "The capital of Mexico is Mexico City",
#                 "The capital of Micronesia is Palikir",
#                 "The capital of Moldova is Chisinau",
#                 "The capital of Monaco is Monaco",
#                 "The capital of Mongolia is Ulaanbaatar",
#                 "The capital of Montenegro is Podgorica",
#                 "The capital of Morocco is Rabat",
#                 "The capital of Mozambique is Maputo",
#                 "The capital of Myanmar (Burma) is Naypyidaw",
#                 "The capital of Namibia is Windhoek",
#                 "The capital of Nauru is Yaren District",
#                 "The capital of Nepal is Kathmandu",
#                 "The capital of Netherlands is Amsterdam",
#                 "The capital of New Zealand is Wellington",
#                 "The capital of Nicaragua is Managua",
#                 "The capital of Niger is Niamey",
#                 "The capital of Nigeria is Abuja",
#                 "The capital of North Korea is Pyongyang",
#                 "The capital of North Macedonia (fmr. Macedonia) is Skopje",
#                 "The capital of Norway is Oslo",
#                 "The capital of Oman is Muscat",
#                 "The capital of Pakistan is Islamabad",
#                 "The capital of Palau is Ngerulmud",
#                 "The capital of Panama is Panama City",
#                 "The capital of Papua New Guinea is Port Moresby",
#                 "The capital of Paraguay is Asunci\u0623\u00b3n",
#                 "The capital of Peru is Lima",
#                 "The capital of Philippines is Manila",
#                 "The capital of Poland is Warsaw",
#                 "The capital of Portugal is Lisbon",
#                 "The capital of Qatar is Doha",
#                 "The capital of Romania is Bucharest",
#                 "The capital of Russia is Moscow",
#                 "The capital of Rwanda is Kigali",
#                 "The capital of Saint Kitts and Nevis is Basseterre",
#                 "The capital of Saint Lucia is Castries",
#                 "The capital of Saint Vincent and the Grenadines is Kingstown",
#                 "The capital of Samoa is Apia",
#                 "The capital of San Marino is San Marino",
#                 "The capital of Sao Tome and Principe is Sao Tome",
#                 "The capital of Saudi Arabia is Riyadh",
#                 "The capital of Senegal is Dakar",
#                 "The capital of Serbia is Belgrade",
#                 "The capital of Seychelles is Victoria",
#                 "The capital of Sierra Leone is Freetown",
#                 "The capital of Singapore is Singapore",
#                 "The capital of Slovakia is Bratislava",
#                 "The capital of Slovenia is Ljubljana",
#                 "The capital of Solomon Islands is Honiara",
#                 "The capital of Somalia is Mogadishu",
#                 "The capital of South Africa is Pretoria, Bloemfontein, Cape Town",
#                 "The capital of South Korea is Seoul",
#                 "The capital of South Sudan is Juba",
#                 "The capital of Spain is Madrid",
#                 "The capital of Sri Lanka is Sri Jayawardenepura Kotte",
#                 "The capital of Sudan is Khartoum",
#                 "The capital of Suriname is Paramaribo",
#                 "The capital of Sweden is Stockholm",
#                 "The capital of Switzerland is Bern",
#                 "The capital of Syria is Damascus",
#                 "The capital of Taiwan is Taipei",
#                 "The capital of Tajikistan is Dushanbe",
#                 "The capital of Tanzania is Dodoma",
#                 "The capital of Thailand is Bangkok",
#                 "The capital of Togo is Lome",
#                 "The capital of Tonga is Nuku'alofa",
#                 "The capital of Trinidad and Tobago is Port of Spain",
#                 "The capital of Tunisia is Tunis",
#                 "The capital of Turkey is Ankara",
#                 "The capital of Turkmenistan is Ashgabat",
#                 "The capital of Tuvalu is Funafuti",
#                 "The capital of Uganda is Kampala",
#                 "The capital of Ukraine is Kyiv",
#                 "The capital of United Arab Emirates is Abu Dhabi",
#                 "The capital of United Kingdom is London",
#                 "The capital of United States of America is Washington, D.C.",
#                 "The capital of Uruguay is Montevideo",
#                 "The capital of Uzbekistan is Tashkent",
#                 "The capital of Vanuatu is Port Vila",
#                 "The capital of Vatican City is Vatican City",
#                 "The capital of Venezuela is Caracas",
#                 "The capital of Vietnam is Hanoi",
#                 "The capital of Yemen is Sana'a",
#                 "The capital of Zambia is Lusaka",
#                 "The capital of Zimbabwe is Harare"
#             ]
#         }
#     ]
# }

# %% [markdown]
# # Consolidating_Data

# %%
training_sentences = []
training_labels = []
labels = []
responses = []

# Data 1 Processing (intents)
for intent in intents['intents']:
    # Collecting patterns for sentences
    for pattern in intent['patterns']:
        training_sentences.append(pattern)
        training_labels.append(intent['tag'])
    # Collecting responses
    responses.append(intent['responses'])

    # Adding unique tags to the labels list
    if intent['tag'] not in labels:
        labels.append(intent['tag'])

# Data 2 Processing (intents)
for intent in intents['intents']:
    for pattern in intent['patterns']:
        training_sentences.append(pattern)
        training_labels.append(intent['tag'])
    responses.append(intent['responses'])

    if intent['tag'] not in labels:
        labels.append(intent['tag'])

# Data 3 Processing (country)
for intent in country['intents']:
    for pattern in intent['patterns']:
        training_sentences.append(pattern)
        training_labels.append(intent['tag'])
    responses.append(intent['responses'])

    if intent['tag'] not in labels:
        labels.append(intent['tag'])

# Data 4 Processing (intents_arabic)
for intent in intents_arabic['intents']:
    for pattern in intent['patterns']:
        training_sentences.append(pattern)
        training_labels.append(intent['tag'])
    responses.append(intent['responses'])

    # Appending only if the tag is not already in the labels list
    if intent['tag'] in labels:
        labels.append(intent['tag'])

# Number of unique classes (intents or labels)
num_classes = len(labels)
num_classes
# Out:
# 27

# %% [markdown]
#  1. Initialization: Initializes empty lists: training_sentences, training_labels, labels, and responses.
#
# 2. Data Processing - Intents 1: Processes data related to intents from the intents source:
#    Iterates through each intent in the 'intents' data.
#    Collects patterns (sentences) and corresponding tags (labels) from each intent.
#    Gathers responses associated with each intent.
#    Adds unique tags to the labels list if they're not already present.
# 3. Data Processing - Intents 2: Processes another set of data related to intents from the same intents source:
#
#     Similar to the first intent processing, it appends patterns, labels, and responses to their respective lists.
#     Checks and adds unique tags to the labels list.
# 4. Data Processing - Country: Processes data related to 'country' intents:
#
#     Gathers patterns, labels, and responses from the 'country' intents.
#     Adds unique tags to the labels list if they're not already present.
# 5. Data Processing - Intents Arabic: Processes data related to intents in Arabic:
#
#     Gathers patterns, labels, and responses from the 'intents_arabic' source.
#     Appends tags to the labels list if they are already present.
# 6. Counting Unique Classes: Determines the number of unique classes (intents or labels) by calculating the length of the labels list, which represents the unique tags gathered from the processed data sources.

# %% [markdown]
# # Label_Encoder

# %%
# Initialize a LabelEncoder object
le = LabelEncoder()

# Fit the LabelEncoder to the training labels to transform them into numerical labels
le.fit(training_labels)

# Transform the original training labels into numerical labels
training_labels = le.transform(training_labels)

# Display the transformed training labels
training_labels
# Out:
# array([10, 10, 10, 10, 10, 10,  9,  9,  9,  9,  9, 17, 17, 17, 17, 17,  0,
#         0,  0,  0,  0, 13, 13, 13, 11, 11, 11, 11, 11, 11, 11,  6,  6,  6,
#         6, 15, 15, 15, 15,  3,  3,  3,  3,  7,  7,  7, 16, 16, 16, 16,  4,
#         4,  4,  4, 12, 12, 12, 14, 14, 14,  1,  1,  1,  8,  8,  8,  5,  5,
#         5, 10, 10, 10, 10, 10, 10,  9,  9,  9,  9,  9, 17, 17, 17, 17, 17,
#         0,  0,  0,  0,  0, 13, 13, 13, 11, 11, 11, 11, 11, 11, 11,  6,  6,
#         6,  6, 15, 15, 15, 15,  3,  3,  3,  3,  7,  7,  7, 16, 16, 16, 16,
#         4,  4,  4,  4, 12, 12, 12, 14, 14, 14,  1,  1,  1,  8,  8,  8,  5,
#         5,  5,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,
#         2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,
#         2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,
#         2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,
#         2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,
#         2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,
#         2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,
#         2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,
#         2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,
#         2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,
#         2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,
#         2,  2,  2,  2,  2,  2,  2,  2,  2,  6,  6,  6, 15, 15, 15,  3,  3,
#         3,  6,  6,  6, 15, 15, 15,  3,  3,  3,  6,  6,  6, 15, 15, 15,  3,
#         3,  3])

# %% [markdown]
# 1. LabelEncoder Initialization: Creates a LabelEncoder object named le.
#
# 2. Fitting the LabelEncoder: The fit() method of the LabelEncoder is used to fit the encoder to the training_labels. This step basically identifies unique labels in training_labels and assigns a unique numerical value to each unique label.
#
# 3. Transforming Training Labels: The transform() method of the LabelEncoder is applied to training_labels. It replaces each label in training_labels with its corresponding encoded numerical value obtained from the fitting step.
#
# 3. Display Transformed Labels: The training_labels variable now contains the numerical representations of the original categorical labels after transformation using the LabelEncoder. The code snippet concludes by displaying the transformed labels in the output.

# %% [markdown]
# # Text Tokenization and Sequence Padding

# %%
# Setting parameters
vocab_size = 1000  # Maximum number of words to keep in the vocabulary
embedding_dim = 16  # Dimension of the word embedding
max_len = 20  # Maximum length of sequences
oov_token = "<OOV>"  # Out-of-vocabulary token

# Initializing a Tokenizer object with specified parameters
tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_token)

# Creating a word index based on the training sentences
tokenizer.fit_on_texts(training_sentences)

# Retrieving the word index generated by the Tokenizer
word_index = tokenizer.word_index

# Converting text sentences to sequences of integers using the word index
sequences = tokenizer.texts_to_sequences(training_sentences)

# Padding sequences to ensure uniform length (truncating longer sequences)
padded_sequences = pad_sequences(sequences, truncating='post', maxlen=max_len)

# %% [markdown]
# 1. Setting Parameters: Defines parameters such as vocabulary size (vocab_size), embedding dimension (embedding_dim), maximum sequence length (max_len), and an out-of-vocabulary token (oov_token).
#
# 2. Tokenizer Initialization: Creates a Tokenizer object with the specified parameters (limited vocabulary size and out-of-vocabulary token).
#
# 3. Fitting Tokenizer: fit_on_texts() method tokenizes and builds the word index based on the training sentences provided (training_sentences).
#
# 4. Word Index Retrieval: Retrieves the word index generated by the Tokenizer, containing the mapping of words to numerical indices.
#
# 5. Text to Sequences: Converts text sentences (training_sentences) to sequences of integers using the word index obtained from the Tokenizer.
#
# 6. Sequence Padding: Pads sequences to ensure uniform length (max_len). Longer sequences are truncated from the end (truncating='post') to match the specified maximum length.

# %% [markdown]
# # Model

# %%
# Create a Sequential model
model = Sequential()

# Add an Embedding layer with specified parameters to the model
model.add(Embedding(vocab_size, embedding_dim, input_length=max_len))

# Add GlobalAveragePooling1D layer to the model
model.add(GlobalAveragePooling1D())

# Add a Dense layer with 16 units and ReLU activation function to the model
model.add(Dense(16, activation='relu'))

# Add another Dense layer with 16 units and ReLU activation function to the model
model.add(Dense(16, activation='relu'))

# Add a Dense output layer with 'num_classes' units and softmax activation function for classification
model.add(Dense(num_classes, activation='softmax'))

# Compile the model using sparse categorical crossentropy loss, Adam optimizer, and accuracy metric
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Display the summary of the model architecture
model.summary()
# Out:
# WARNING:tensorflow:From C:\conda11\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\conda11\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 20, 16)            16000
#
#  global_average_pooling1d (  (None, 16)                0
#  GlobalAveragePooling1D)
#
#  dense (Dense)               (None, 16)                272
#
#  dense_1 (Dense)             (None, 16)                272
#
#  dense_2 (Dense)             (None, 27)                459
#
# =================================================================
# Total params: 17003 (66.42 KB)
# Trainable params: 17003 (66.42 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# 1. Sequential Model Creation: Initializes a Sequential model.
#
# 2. Embedding Layer: Adds an Embedding layer to the model. This layer converts words into fixed-size dense vectors (word embeddings). Parameters like vocab_size (size of the vocabulary), embedding_dim (dimension of the embeddings), and input_length (length of input sequences) are specified.
#
# 3. GlobalAveragePooling1D Layer: Adds a Global Average Pooling 1D layer to the model. This layer reduces the dimensionality of the output from the Embedding layer by taking the average of all the embeddings. It creates a fixed-length output regardless of the input sequence length.
#
# 4. Dense Layers: Adds two Dense layers with 16 units each and ReLU activation functions. These dense layers help in learning complex patterns in the data.
#
# 5. utput Layer: Adds a Dense output layer with num_classes units (representing the number of unique classes in the classification task) and uses a softmax activation function. Softmax ensures that the output values represent probabilities for each class.
#
# 6. Model Compilation: Compiles the model with settings for loss, optimizer, and metrics.
#
#    Loss function: Sparse Categorical Crossentropy - suitable for multi-class classification tasks with integer labels.
#    Optimizer: Adam - an efficient and widely used optimization algorithm.
#    Metrics: Accuracy - to measure the model's performance during training.
# 7. Model Summary: Displays a summary of the model architecture, including the layers, their types, output shapes, and trainable parameters.

# %% [markdown]
# # Training_Model

# %%
epochs = 500
history = model.fit(
    padded_sequences,
    np.array(training_labels),  
    epochs=epochs
)
# Out:
# Epoch 1/500
# WARNING:tensorflow:From C:\conda11\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\conda11\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 12/12 [==============================] - 4s 7ms/step - loss: 3.2794 - accuracy: 0.4262
# Epoch 2/500
# 12/12 [==============================] - 0s 6ms/step - loss: 3.2396 - accuracy: 0.5404
# Epoch 3/500
# 12/12 [==============================] - 0s 5ms/step - loss: 3.1867 - accuracy: 0.5404
# Epoch 4/500
# 12/12 [==============================] - 0s 7ms/step - loss: 3.1107 - accuracy: 0.5404
# Epoch 5/500
# 12/12 [==============================] - 0s 6ms/step - loss: 2.9994 - accuracy: 0.5404
# Epoch 6/500
# 12/12 [==============================] - 0s 6ms/step - loss: 2.8423 - accuracy: 0.5404
# Epoch 7/500
# 12/12 [==============================] - 0s 7ms/step - loss: 2.6348 - accuracy: 0.5404
# Epoch 8/500
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3697 - accuracy: 0.5404
# Epoch 9/500
# 12/12 [==============================] - 0s 9ms/step - loss: 2.1090 - accuracy: 0.5404
# Epoch 10/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.9435 - accuracy: 0.5404
# Epoch 11/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.8786 - accuracy: 0.5404
# Epoch 12/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.8348 - accuracy: 0.5404
# Epoch 13/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.7954 - accuracy: 0.5404
# Epoch 14/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.7602 - accuracy: 0.5404
# Epoch 15/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.7263 - accuracy: 0.5404
# Epoch 16/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.6945 - accuracy: 0.5404
# Epoch 17/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.6625 - accuracy: 0.5404
# Epoch 18/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.6309 - accuracy: 0.5404
# Epoch 19/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.5976 - accuracy: 0.5404
# Epoch 20/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.5646 - accuracy: 0.5432
# Epoch 21/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.5318 - accuracy: 0.5460
# Epoch 22/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.4979 - accuracy: 0.5460
# Epoch 23/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.4653 - accuracy: 0.5543
# Epoch 24/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.4364 - accuracy: 0.5627
# Epoch 25/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.4089 - accuracy: 0.5738
# Epoch 26/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.3835 - accuracy: 0.5794
# Epoch 27/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.3601 - accuracy: 0.5877
# Epoch 28/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.3360 - accuracy: 0.5877
# Epoch 29/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.3150 - accuracy: 0.5877
# Epoch 30/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.2946 - accuracy: 0.5933
# Epoch 31/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.2768 - accuracy: 0.6156
# Epoch 32/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2587 - accuracy: 0.6184
# Epoch 33/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.2409 - accuracy: 0.6184
# Epoch 34/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.2221 - accuracy: 0.6156
# Epoch 35/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2039 - accuracy: 0.6184
# Epoch 36/500
# 12/12 [==============================] - 0s 5ms/step - loss: 1.1859 - accuracy: 0.6184
# Epoch 37/500
# 12/12 [==============================] - 0s 8ms/step - loss: 1.1683 - accuracy: 0.6184
# Epoch 38/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.1508 - accuracy: 0.6184
# Epoch 39/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.1347 - accuracy: 0.6184
# Epoch 40/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.1173 - accuracy: 0.6240
# Epoch 41/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.1012 - accuracy: 0.6240
# Epoch 42/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.0846 - accuracy: 0.6240
# Epoch 43/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.0689 - accuracy: 0.6240
# Epoch 44/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.0523 - accuracy: 0.6295
# Epoch 45/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.0378 - accuracy: 0.6323
# Epoch 46/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.0224 - accuracy: 0.6462
# Epoch 47/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.0083 - accuracy: 0.6435
# Epoch 48/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.9934 - accuracy: 0.6546
# Epoch 49/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.9804 - accuracy: 0.6546
# Epoch 50/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.9673 - accuracy: 0.7214
# Epoch 51/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.9538 - accuracy: 0.7019
# Epoch 52/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.9404 - accuracy: 0.6852
# Epoch 53/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.9292 - accuracy: 0.6741
# Epoch 54/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.9171 - accuracy: 0.6825
# Epoch 55/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.9054 - accuracy: 0.6713
# Epoch 56/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.8960 - accuracy: 0.6908
# Epoch 57/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.8841 - accuracy: 0.7242
# Epoch 58/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.8736 - accuracy: 0.7187
# Epoch 59/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.8622 - accuracy: 0.6992
# Epoch 60/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.8536 - accuracy: 0.6936
# Epoch 61/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.8441 - accuracy: 0.7159
# Epoch 62/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.8334 - accuracy: 0.7047
# Epoch 63/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.8247 - accuracy: 0.7075
# Epoch 64/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.8150 - accuracy: 0.7187
# Epoch 65/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.8070 - accuracy: 0.7242
# Epoch 66/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.7980 - accuracy: 0.7047
# Epoch 67/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7919 - accuracy: 0.7270
# Epoch 68/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7818 - accuracy: 0.7437
# Epoch 69/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7735 - accuracy: 0.7103
# Epoch 70/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.7660 - accuracy: 0.6992
# Epoch 71/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7597 - accuracy: 0.7242
# Epoch 72/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.7519 - accuracy: 0.7214
# Epoch 73/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.7473 - accuracy: 0.7214
# Epoch 74/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7375 - accuracy: 0.7270
# Epoch 75/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7297 - accuracy: 0.7242
# Epoch 76/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7249 - accuracy: 0.7270
# Epoch 77/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7179 - accuracy: 0.7103
# Epoch 78/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7116 - accuracy: 0.7103
# Epoch 79/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.7035 - accuracy: 0.7298
# Epoch 80/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6942 - accuracy: 0.7326
# Epoch 81/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6921 - accuracy: 0.7131
# Epoch 82/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6851 - accuracy: 0.6992
# Epoch 83/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6751 - accuracy: 0.7159
# Epoch 84/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6695 - accuracy: 0.7409
# Epoch 85/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6628 - accuracy: 0.7326
# Epoch 86/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6567 - accuracy: 0.7521
# Epoch 87/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6485 - accuracy: 0.7799
# Epoch 88/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6441 - accuracy: 0.7772
# Epoch 89/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6354 - accuracy: 0.7688
# Epoch 90/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6295 - accuracy: 0.7827
# Epoch 91/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6272 - accuracy: 0.7744
# Epoch 92/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6179 - accuracy: 0.7772
# Epoch 93/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6129 - accuracy: 0.7994
# Epoch 94/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6019 - accuracy: 0.8078
# Epoch 95/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.5971 - accuracy: 0.7967
# Epoch 96/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.5918 - accuracy: 0.7772
# Epoch 97/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.5853 - accuracy: 0.7855
# Epoch 98/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.5795 - accuracy: 0.8050
# Epoch 99/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.5708 - accuracy: 0.8050
# Epoch 100/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.5620 - accuracy: 0.8217
# Epoch 101/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.5550 - accuracy: 0.8329
# Epoch 102/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.5468 - accuracy: 0.8579
# Epoch 103/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.5376 - accuracy: 0.8607
# Epoch 104/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.5285 - accuracy: 0.8579
# Epoch 105/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.5260 - accuracy: 0.8329
# Epoch 106/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.5136 - accuracy: 0.8719
# Epoch 107/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.5024 - accuracy: 0.8663
# Epoch 108/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.4967 - accuracy: 0.8635
# Epoch 109/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.4903 - accuracy: 0.9053
# Epoch 110/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.4792 - accuracy: 0.9109
# Epoch 111/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4721 - accuracy: 0.9025
# Epoch 112/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.4609 - accuracy: 0.9192
# Epoch 113/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.4572 - accuracy: 0.9081
# Epoch 114/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4488 - accuracy: 0.9136
# Epoch 115/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.4396 - accuracy: 0.8969
# Epoch 116/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4286 - accuracy: 0.8969
# Epoch 117/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4237 - accuracy: 0.9192
# Epoch 118/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.4154 - accuracy: 0.9136
# Epoch 119/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4067 - accuracy: 0.8942
# Epoch 120/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.3951 - accuracy: 0.9220
# Epoch 121/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.3872 - accuracy: 0.9304
# Epoch 122/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.3771 - accuracy: 0.9387
# Epoch 123/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.3690 - accuracy: 0.9471
# Epoch 124/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.3609 - accuracy: 0.9666
# Epoch 125/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.3507 - accuracy: 0.9526
# Epoch 126/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.3469 - accuracy: 0.9638
# Epoch 127/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.3400 - accuracy: 0.9331
# Epoch 128/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.3272 - accuracy: 0.9415
# Epoch 129/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.3226 - accuracy: 0.9359
# Epoch 130/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.3114 - accuracy: 0.9638
# Epoch 131/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.3045 - accuracy: 0.9526
# Epoch 132/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2929 - accuracy: 0.9610
# Epoch 133/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2889 - accuracy: 0.9471
# Epoch 134/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.2796 - accuracy: 0.9749
# Epoch 135/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2678 - accuracy: 0.9833
# Epoch 136/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2645 - accuracy: 0.9749
# Epoch 137/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2563 - accuracy: 0.9749
# Epoch 138/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2467 - accuracy: 0.9805
# Epoch 139/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2394 - accuracy: 0.9833
# Epoch 140/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2329 - accuracy: 0.9833
# Epoch 141/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2299 - accuracy: 0.9694
# Epoch 142/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2221 - accuracy: 0.9777
# Epoch 143/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2165 - accuracy: 0.9889
# Epoch 144/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2111 - accuracy: 0.9833
# Epoch 145/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2041 - accuracy: 0.9833
# Epoch 146/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1987 - accuracy: 0.9861
# Epoch 147/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1924 - accuracy: 0.9833
# Epoch 148/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1888 - accuracy: 0.9833
# Epoch 149/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1842 - accuracy: 0.9861
# Epoch 150/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1784 - accuracy: 0.9861
# Epoch 151/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1740 - accuracy: 0.9833
# Epoch 152/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1706 - accuracy: 0.9833
# Epoch 153/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1654 - accuracy: 0.9833
# Epoch 154/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1614 - accuracy: 0.9833
# Epoch 155/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1563 - accuracy: 0.9833
# Epoch 156/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1528 - accuracy: 0.9861
# Epoch 157/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1513 - accuracy: 0.9833
# Epoch 158/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1449 - accuracy: 0.9861
# Epoch 159/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1412 - accuracy: 0.9833
# Epoch 160/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1380 - accuracy: 0.9833
# Epoch 161/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1352 - accuracy: 0.9833
# Epoch 162/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1307 - accuracy: 0.9833
# Epoch 163/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1293 - accuracy: 0.9861
# Epoch 164/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1253 - accuracy: 0.9889
# Epoch 165/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1210 - accuracy: 0.9833
# Epoch 166/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1186 - accuracy: 0.9889
# Epoch 167/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1179 - accuracy: 0.9944
# Epoch 168/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1128 - accuracy: 0.9916
# Epoch 169/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1127 - accuracy: 0.9889
# Epoch 170/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1092 - accuracy: 0.9944
# Epoch 171/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1046 - accuracy: 0.9916
# Epoch 172/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1032 - accuracy: 0.9861
# Epoch 173/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1013 - accuracy: 0.9861
# Epoch 174/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0996 - accuracy: 0.9889
# Epoch 175/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0960 - accuracy: 0.9944
# Epoch 176/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0936 - accuracy: 0.9944
# Epoch 177/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0904 - accuracy: 0.9916
# Epoch 178/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0888 - accuracy: 0.9889
# Epoch 179/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0868 - accuracy: 0.9889
# Epoch 180/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0832 - accuracy: 0.9944
# Epoch 181/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0815 - accuracy: 0.9889
# Epoch 182/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0803 - accuracy: 0.9944
# Epoch 183/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0782 - accuracy: 0.9944
# Epoch 184/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0771 - accuracy: 0.9889
# Epoch 185/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0743 - accuracy: 0.9944
# Epoch 186/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0731 - accuracy: 0.9944
# Epoch 187/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0711 - accuracy: 0.9944
# Epoch 188/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0697 - accuracy: 0.9889
# Epoch 189/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0669 - accuracy: 0.9916
# Epoch 190/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0672 - accuracy: 0.9944
# Epoch 191/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0649 - accuracy: 0.9944
# Epoch 192/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0642 - accuracy: 0.9889
# Epoch 193/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0622 - accuracy: 0.9889
# Epoch 194/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0600 - accuracy: 0.9944
# Epoch 195/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0592 - accuracy: 0.9944
# Epoch 196/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0585 - accuracy: 0.9889
# Epoch 197/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0561 - accuracy: 0.9944
# Epoch 198/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0568 - accuracy: 0.9916
# Epoch 199/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0539 - accuracy: 0.9944
# Epoch 200/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0531 - accuracy: 0.9944
# Epoch 201/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0514 - accuracy: 0.9944
# Epoch 202/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0503 - accuracy: 0.9944
# Epoch 203/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0492 - accuracy: 0.9944
# Epoch 204/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0484 - accuracy: 0.9944
# Epoch 205/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0469 - accuracy: 0.9944
# Epoch 206/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0466 - accuracy: 0.9944
# Epoch 207/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0455 - accuracy: 0.9944
# Epoch 208/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0444 - accuracy: 0.9944
# Epoch 209/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0446 - accuracy: 0.9916
# Epoch 210/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0421 - accuracy: 0.9972
# Epoch 211/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0418 - accuracy: 0.9944
# Epoch 212/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0412 - accuracy: 0.9972
# Epoch 213/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0408 - accuracy: 0.9944
# Epoch 214/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0395 - accuracy: 0.9944
# Epoch 215/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0388 - accuracy: 1.0000
# Epoch 216/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0375 - accuracy: 0.9972
# Epoch 217/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0367 - accuracy: 0.9944
# Epoch 218/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0356 - accuracy: 1.0000
# Epoch 219/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0353 - accuracy: 1.0000
# Epoch 220/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0349 - accuracy: 1.0000
# Epoch 221/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0342 - accuracy: 0.9944
# Epoch 222/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0331 - accuracy: 1.0000
# Epoch 223/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0328 - accuracy: 1.0000
# Epoch 224/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0321 - accuracy: 1.0000
# Epoch 225/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0316 - accuracy: 0.9944
# Epoch 226/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0307 - accuracy: 1.0000
# Epoch 227/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0299 - accuracy: 1.0000
# Epoch 228/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0304 - accuracy: 1.0000
# Epoch 229/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0295 - accuracy: 0.9944
# Epoch 230/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0292 - accuracy: 1.0000
# Epoch 231/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0277 - accuracy: 1.0000
# Epoch 232/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 233/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0270 - accuracy: 1.0000
# Epoch 234/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0267 - accuracy: 1.0000
# Epoch 235/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0264 - accuracy: 1.0000
# Epoch 236/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0254 - accuracy: 1.0000
# Epoch 237/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0249 - accuracy: 1.0000
# Epoch 238/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0247 - accuracy: 1.0000
# Epoch 239/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0241 - accuracy: 1.0000
# Epoch 240/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0238 - accuracy: 1.0000
# Epoch 241/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0231 - accuracy: 1.0000
# Epoch 242/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0229 - accuracy: 1.0000
# Epoch 243/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0228 - accuracy: 1.0000
# Epoch 244/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 245/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0219 - accuracy: 1.0000
# Epoch 246/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0214 - accuracy: 1.0000
# Epoch 247/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0214 - accuracy: 1.0000
# Epoch 248/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0210 - accuracy: 1.0000
# Epoch 249/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 250/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0202 - accuracy: 1.0000
# Epoch 251/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0195 - accuracy: 1.0000
# Epoch 252/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0192 - accuracy: 1.0000
# Epoch 253/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 254/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0191 - accuracy: 1.0000
# Epoch 255/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 256/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 257/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0184 - accuracy: 1.0000
# Epoch 258/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 259/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 260/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 261/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 262/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 263/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 264/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 265/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 266/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 267/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0148 - accuracy: 1.0000
# Epoch 268/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 269/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 270/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 271/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 272/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 273/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 274/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 275/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 276/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 277/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 278/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 279/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 280/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 281/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 282/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 283/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 284/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 285/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 286/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 287/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 288/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 289/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 290/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 291/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 292/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 293/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 294/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 295/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 296/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 297/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 298/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 299/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 300/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 301/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 302/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 303/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 304/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 305/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 306/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 307/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 308/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 309/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 310/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 311/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 312/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 313/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 314/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 315/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 316/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 317/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 318/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 319/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 320/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 321/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 322/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 323/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 324/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 325/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 326/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 327/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 328/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 329/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 330/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 331/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 332/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 333/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 334/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 335/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 336/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 337/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 338/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 339/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 340/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 341/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 342/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 343/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 344/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 345/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 346/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 347/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 348/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 349/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 350/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 351/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 352/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 353/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 354/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 355/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 356/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 357/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 358/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 359/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 360/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 361/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 362/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 363/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 364/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 365/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 366/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 367/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 368/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 369/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 370/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 371/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 372/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 373/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 374/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 375/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 376/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 377/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 378/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 379/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 380/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 381/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 382/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 383/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 384/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 385/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 386/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 387/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 388/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 389/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 390/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 391/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 392/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 393/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 394/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 395/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 396/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 397/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 398/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 399/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 400/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 401/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 402/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 403/500
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 404/500
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 405/500
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 406/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 407/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 408/500
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 409/500
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 410/500
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 411/500
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 412/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 413/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 414/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 415/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 416/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 417/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 418/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 419/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 420/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 421/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 422/500
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 423/500
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 424/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 425/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 426/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 427/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 428/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 429/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 430/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 431/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 432/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 433/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 434/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 435/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 436/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 437/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 438/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 439/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 440/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 441/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 442/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 443/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 444/500
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 445/500
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 446/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 447/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 448/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 449/500
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 450/500
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 451/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 452/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 453/500
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 454/500
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 455/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 456/500
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 457/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 458/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 459/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 460/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 461/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 462/500
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 463/500
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 464/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 465/500
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 466/500
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 467/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 468/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 469/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 470/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 471/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 472/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 473/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 474/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 475/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 476/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 477/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 478/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 479/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 480/500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 481/500
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 482/500
# 12/12 [==============================] - 0s 9ms/step - loss: 9.8831e-04 - accuracy: 1.0000
# Epoch 483/500
# 12/12 [==============================] - 0s 7ms/step - loss: 9.8204e-04 - accuracy: 1.0000
# Epoch 484/500
# 12/12 [==============================] - 0s 8ms/step - loss: 9.7140e-04 - accuracy: 1.0000
# Epoch 485/500
# 12/12 [==============================] - 0s 9ms/step - loss: 9.6608e-04 - accuracy: 1.0000
# Epoch 486/500
# 12/12 [==============================] - 0s 9ms/step - loss: 9.5297e-04 - accuracy: 1.0000
# Epoch 487/500
# 12/12 [==============================] - 0s 7ms/step - loss: 9.6305e-04 - accuracy: 1.0000
# Epoch 488/500
# 12/12 [==============================] - 0s 8ms/step - loss: 9.7142e-04 - accuracy: 1.0000
# Epoch 489/500
# 12/12 [==============================] - 0s 8ms/step - loss: 9.6630e-04 - accuracy: 1.0000
# Epoch 490/500
# 12/12 [==============================] - 0s 8ms/step - loss: 9.3996e-04 - accuracy: 1.0000
# Epoch 491/500
# 12/12 [==============================] - 0s 8ms/step - loss: 9.0807e-04 - accuracy: 1.0000
# Epoch 492/500
# 12/12 [==============================] - 0s 7ms/step - loss: 8.9951e-04 - accuracy: 1.0000
# Epoch 493/500
# 12/12 [==============================] - 0s 7ms/step - loss: 8.8635e-04 - accuracy: 1.0000
# Epoch 494/500
# 12/12 [==============================] - 0s 7ms/step - loss: 8.9014e-04 - accuracy: 1.0000
# Epoch 495/500
# 12/12 [==============================] - 0s 7ms/step - loss: 8.8712e-04 - accuracy: 1.0000
# Epoch 496/500
# 12/12 [==============================] - 0s 8ms/step - loss: 8.8071e-04 - accuracy: 1.0000
# Epoch 497/500
# 12/12 [==============================] - 0s 7ms/step - loss: 8.6064e-04 - accuracy: 1.0000
# Epoch 498/500
# 12/12 [==============================] - 0s 8ms/step - loss: 8.4121e-04 - accuracy: 1.0000
# Epoch 499/500
# 12/12 [==============================] - 0s 8ms/step - loss: 8.3170e-04 - accuracy: 1.0000
# Epoch 500/500
# 12/12 [==============================] - 0s 8ms/step - loss: 8.2740e-04 - accuracy: 1.0000

# %% [markdown]
# # Model Preservation

# %%
model.save("chat_model")  # Saving the trained model as "chat_model" for future use.

import pickle  # Importing pickle for serialization.

# Saving the fitted tokenizer using pickle serialization:
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# Saving the fitted label encoder using pickle serialization:
with open('label_encoder.pickle', 'wb') as ecn_file:
    pickle.dump(le, ecn_file, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# INFO:tensorflow:Assets written to: chat_model\assets
# INFO:tensorflow:Assets written to: chat_model\assets

# %% [markdown]
# # Main

# %%
# Import necessary libraries and modules
import requests
import json 
import numpy as np
from tensorflow import keras
from sklearn.preprocessing import LabelEncoder
from fuzzywuzzy import fuzz

import colorama 
colorama.init()
from colorama import Fore, Style, Back

import random
import pickle

# Load intents from JSON files
with open("intents.json") as file:
    data = json.load(file)
with open("Intent.json",encoding='utf-8') as file:
    data2 = json.load(file)
with open("country.json") as file:
    data3 = json.load(file)
with open("intents_arabic.json",encoding='utf-8') as file:
    data4 = json.load(file)
with open ("health.json") as file:
    data5=json.load(file)
with open ("Booking.json") as file:
    data6=json.load(file)

# Function to start the chatbot
def chat():
    # load trained model
    model = keras.models.load_model('chat_model')

    # load tokenizer object
    with open('tokenizer.pickle', 'rb') as handle:
        tokenizer = pickle.load(handle)

    # load label encoder object
    with open('label_encoder.pickle', 'rb') as enc:
        lbl_encoder = pickle.load(enc)

    # parameters
    max_len = 20

    while True:
        # Take user input
        inp = input(Fore.LIGHTBLUE_EX + "You: " + Style.RESET_ALL)
        if inp.lower() == "quit":
            print("See you soon my friend")
            break
        
        print(Fore.LIGHTBLUE_EX + "You:" + Style.RESET_ALL, inp)  # Display user input

        # Initialize variables for best response based on input similarity
        best_similarity = -1
        best_response = None

        # Check similarity of input with patterns in the first set of data
        for intent in data['intents']:
            for idx, pattern in enumerate(intent['patterns']):
                if idx < len(intent['responses']):
                    similarity = fuzz.partial_ratio(inp.lower(), pattern.lower())
                    if similarity > best_similarity:
                        best_similarity = similarity
                        best_response = intent['responses'][idx]
        
        # Check similarity of input with patterns in the second set of data
        for intent in data2['intents']:  
            for idx, pattern in enumerate(intent['patterns']):
                if idx < len(intent['responses']):
                    similarity = fuzz.partial_ratio(inp.lower(), pattern.lower())
                    if similarity > best_similarity:
                        best_similarity = similarity
                        best_response = intent['responses'][idx]
        
        # Check similarity of input with patterns in the third set of data
        for intent in data3['intents']:  
            for idx, pattern in enumerate(intent['patterns']):
                if idx < len(intent['responses']):
                    similarity = fuzz.partial_ratio(inp.lower(), pattern.lower())
                    if similarity > best_similarity:
                        best_similarity = similarity
                        best_response = intent['responses'][idx]
        
        # Check similarity of input with patterns in the fourth set of data
        for intent in data4['intents']:
            for idx, pattern in enumerate(intent['patterns']):
                if idx < len(intent['responses']):
                    similarity = fuzz.partial_ratio(inp.lower(), pattern.lower())
                    if similarity > best_similarity:
                        best_similarity = similarity
                        best_response = intent['responses'][idx]
        
        # Check similarity of input with patterns in the fifth set of data
        for intent in data5['intents']:
            for idx, pattern in enumerate(intent['patterns']):
                if idx < len(intent['responses']):
                    similarity = fuzz.partial_ratio(inp.lower(), pattern.lower())
                    if similarity > best_similarity:
                        best_similarity = similarity
                        best_response = intent['responses'][idx]
        
        # Check similarity of input with patterns in the sixth set of data
        for intent in data6['intents']:
            for idx, pattern in enumerate(intent['patterns']):
                if idx < len(intent['responses']):
                    similarity = fuzz.partial_ratio(inp.lower(), pattern.lower())
                    if similarity > best_similarity:
                        best_similarity = similarity
                        best_response = intent['responses'][idx]
        
        # Provide response based on similarity threshold
        if best_similarity > 70 and best_response:  # Set a threshold for similarity
            print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL, best_response)
        else:
            print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL, "Write correctly. You are the one who is wrong. I am definitely correct")
# Out:
# C:\conda11\Lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# 1. Imports: Import necessary libraries/modules for handling requests, JSON data, array operations, machine learning components (TensorFlow Keras for the neural network), label encoding, fuzzy string matching (fuzzywuzzy), and terminal colors using colorama.
#
# 2. Loading Intent Data: Loads intent data from multiple JSON files into different variables (data, data2, data3, data4, data5, data6).
#
# 3. Chatbot Function (chat()):
#
#     Model Loading: Loads a pre-trained neural network model (chat_model) using Keras' load_model function.
#     Tokenizer and Label Encoder Loading: Loads the tokenizer and label encoder objects from their respective pickle files.
#     User Interaction Loop: Begins a while loop for interaction with the user until the user inputs 'quit'.
#     User Input Processing: Takes user input and processes it.
#     Intent Matching with Fuzzy String Matching:
#     Checks similarity between user input and patterns within each set of intents (from loaded JSON files) using fuzzy string matching.
#     Determines the best response based on the highest similarity score for each set of intents.
#     Response Generation:
#     Provides responses based on the best similarity score found. If the similarity score is above a certain threshold (70 in this case) and a suitable response is found, the chatbot displays the response.
#     If the similarity score is below the threshold or no suitable response is found, it displays a default response indicating an error in the user input.

# %% [markdown]
# # Result

# %%
# Display a message to inform the user how to close the chat
print(Fore.YELLOW + "if you want to close, type 'Quit'!" + Style.RESET_ALL)
chat()  # Start the chatbot function
# Out:
# if you want to close, type 'Quit'!
# WARNING:tensorflow:From C:\conda11\Lib\site-packages\keras\src\saving\legacy\saved_model\load.py:107: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
# WARNING:tensorflow:From C:\conda11\Lib\site-packages\keras\src\saving\legacy\saved_model\load.py:107: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
# You: Hi
# You: Hi
# ChatBot: Hi :)
# You: ما هو الفرق بين الجهد والتيار الكهربائي؟
# You: ما هو الفرق بين الجهد والتيار الكهربائي؟
# ChatBot: الجهد يقاس بالفولت وهو فارق الكهرباء بين نقطتين. التيار يقاس بالأمبير وهو تدفق الكهرباء في الدائرة.
# You: ما هو أفضل نوع من الأنابيب للسباكة؟
# You: ما هو أفضل نوع من الأنابيب للسباكة؟
# ChatBot: البلاستيك والنحاس من أنواع الأنابيب المستخدمة بشكل شائع. اختيار النوع يعتمد على الاحتياجات والبيئة.
# You: ما هي أسباب تسرب المياه في الحمام؟
# You: ما هي أسباب تسرب المياه في الحمام؟
# ChatBot: تسرب المياه في الحمام قد يكون نتيجة لخراب الأختام أو التصاق الجير. يجب إصلاحه فورًا.
# You: What is the capital of Antigua and Barbuda?
# You: What is the capital of Antigua and Barbuda?
# ChatBot: The capital of Antigua and Barbuda is St. John's
# You: quit
# You: quit
# ChatBot: I am sorry to disturb you
# You: Quit
# See you soon my friend
